# %% [markdown]
# # HCI VISUALIZATION

# %% [markdown]
# The code that follows simply prepare the data so it can be visualized

# %%
import pandas as pd
import numpy as np
import ast
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt

# Load Datasets (Assuming files are in the current directory)
# Loading only essential columns for the 'heavy' files to save RAM
# Note: 'ast' will be used later to parse stringified lists in several columns
anime_details_df = pd.read_csv('datasets/details_cleaned.csv')
profiles_df = pd.read_csv('datasets/profiles_cleaned.csv')
ratings_df = pd.read_csv('datasets/ratings_cleaned.csv', usecols=['username', 'anime_id', 'score', 'status']) 
person_voice_works_df = pd.read_csv('datasets/person_voice_works_cleaned.csv')

# We convert dates to datetime immediately for time-series analysis
anime_details_df['start_date'] = pd.to_datetime(anime_details_df['start_date'], errors='coerce')
profiles_df['joined'] = pd.to_datetime(profiles_df['joined'], errors='coerce')
anime_details_df['start_year'] = anime_details_df['start_date'].dt.year

print("Data Loaded Successfully")
# Out:
# Data Loaded Successfully

# %%
# Drop rows where 'start_year' is missing (crucial for timeline analysis)
anime_clean = anime_details_df.dropna(subset=['start_year']).copy()

# Explode 'studios' and take the first studio if multiple exist
# The studios column is stored as a stringified list; ast.literal_eval converts it to a list
anime_clean['studios'] = anime_clean['studios'].apply(ast.literal_eval)
# We treat the first listed studio as the primary studio for each anime
anime_clean['primary_studio'] = anime_clean['studios'].str[0]

# Explode Genres and Demographics
# These columns are a string like "Action, Comedy". We explode it.
# This increases the number of rows, so we save it as a separate DF for genre analysis.
anime_clean['genres'] = anime_clean['genres'].apply(ast.literal_eval)
anime_clean['demographics'] = anime_clean['demographics'].apply(ast.literal_eval)
anime_genres = anime_clean.explode('genres').explode('demographics')

print("Data Cleaned. Ready for Analysis.")
# Out:
# Data Cleaned. Ready for Analysis.

# %% [markdown]
# ## From Local Niche to Global Phenomenon: How Anime Evolved Together with Its Audience

# %% [markdown]
# ### Introduction
# Over the last century, anime has evolved from a small, experimental form of Japanese animation into a global cultural phenomenon followed by millions of people worldwide.
# However, this transformation is not only about how many anime are produced. It is also about how they are distributed, who watches them, how they are rated, and how this audience changes across countries and generations.

# %% [markdown]
# ## CHAPTER 1: The Explosion of the Industry (History & Production)
#
# In this chapter, the idea is to start from production (the industry), move on to content (what is produced) and finish with the audience (who watches).
#
# ### Let's start with this question: How the type of anime distribution is changing?
# We want to observe the distribution of anime from the 1920s to our days

# %%
# CLEANING THE YEARS
# Ensure start_year is numeric
anime_clean['start_year'] = anime_clean['start_year'].astype(int)

# There are too many genres to plot them all. Let's keep only the Top 10 most popular.
top_genres = anime_genres['genres'].value_counts().head(10).index
filtered_data = anime_genres[anime_genres['genres'].isin(top_genres)]

# %%
# count anime by "start_date"
anime_counts = anime_clean["start_date"].dt.year.value_counts().sort_index()

anime_counts.plot(kind='bar')
plt.title('Anime count distribution')
plt.xlabel("Anno")
plt.ylabel("Anime count")
 
plt.show()

# %% [markdown]
# It is possible to observe the trend for each individual year in a very specific and detailed way, as the values are shown on an annual basis. However, the large number of data points on the x-axis makes the chart difficult to read and interpret overall. With the next chart, the trend will be more readable but also more approximate, as the data will be aggregated by decades rather than by individual years.

# %%
# to represent decade
anime_clean["decade"] = ((anime_clean["start_date"].dt.year // 10) * 10).astype("Int64")
film_counts_by_decade = anime_clean["decade"].value_counts().sort_index()


# take only the years that are present to compose the decade
years_per_decade = (anime_clean["start_date"].dt.year.groupby(anime_clean["decade"]).nunique())

adjusted_counts = film_counts_by_decade / years_per_decade

# Plot di film_counts_by_decade
plt.plot(adjusted_counts.index, adjusted_counts.values)

plt.title("Start date for anime by decade")
plt.xlabel("Decade")
plt.ylabel("Average number of anime for each decade")
plt.grid(True, axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# We can observe a roughly linear growth, while the decline after the 2010s is due to the fact that the decade in question is not yet complete.
# This growth has been steady, but is it immune to external shocks?

# %% [markdown]
# ### Do real-world events change the number of anime in production?

# %%
# Count anime starts per year
timeline = anime_clean['start_year'].value_counts().sort_index().reset_index()
timeline.columns = ['Year', 'Count']

# Filter for the modern era (1960+) to avoid the empty early years
timeline = timeline[timeline['Year'] >= 1960].copy()
timeline = timeline[timeline["Year"] <= 2024]

# --- LINE CHART (Anime Production vs. Historical Shocks) ---
fig = px.line(
    timeline,
    x='Year',
    y='Count',
    title='Resilience of the Industry: Anime Production vs. Historical Shocks',
    labels={'Count': 'New Anime Released'},
    markers=True
)

# --- ANNOTATIONS ---
# Adding context to the data points
fig.add_annotation(x=2020, y=timeline.loc[timeline["Year"]==2020, "Count"].iloc[0],
                   text="COVID-19 Pandemic (Sharp Dip)", showarrow=True, arrowhead=1, yshift=10)

fig.add_annotation(x=1995, y=timeline.loc[timeline["Year"]==1995, "Count"].iloc[0],
                   text="Evangelion Boom", showarrow=True, arrowhead=1, yshift=10)


fig.update_layout(hovermode="x unified")
fig.show()

# %% [markdown]
# Since the dataset also includes scheduled future titles (2025+), we decided to limit the timeline to real, confirmed data up to 2025. This keeps the chart clean, readable, and actually meaningful instead of being influenced by incomplete future projections.
# Looking at the trend, anime production has exploded over the decades, especially from the 2000s onward. Even big events like COVID-19 caused only temporary dips. The industry bounces back quickly and keeps producing a huge amount of content, showing how strong and resilient it is.
#
# But how are these anime distributed? Has technology changed the format?

# %% [markdown]
# ## Usually, on which platforms is anime aired?

# %%
# Now we want to see the type of anime to analyse how are distribute, to do this we use the easier graph that we know, pie chart
details_type = anime_clean.groupby("type").size()
details_type.plot(kind='pie')
plt.title('Anime type distribution')
plt.show()

# %% [markdown]
# We can be observe that TV holds the largest share, while the other distribution channels are fairly evenly distributed. PV and CM are exceptions, as they represent the smallest shares.

# %% [markdown]
# ### How did the different types of anime formats change over time?

# %%
# Aggregate: Count by Year and Type
format_counts = anime_clean.groupby(['start_year', 'type']).size().reset_index(name='count')
format_counts = format_counts[(format_counts['start_year'] >= 1960) & (format_counts['start_year'] <= 2025)]

# Calculate Percentage per Year (Vectorized)
# We merge the yearly totals back to calculate the share
yearly_totals = format_counts.groupby('start_year')['count'].transform('sum')
format_counts['share'] = format_counts['count'] / yearly_totals

# --- AREA CHART (Anime Release Formats Over Time) ---
fig = px.area(
    format_counts,
    x="start_year",
    y="share",
    color="type",
    title="Evolution of Anime Release Formats",
    labels={'share': 'Market Share', 'start_year': 'Year'},
)
fig.show()

# %% [markdown]
# The industry basically moved from “buy this on DVD/VHS” to “watch it online whenever you want.” OVAs were huge back when home video was the big thing, especially in the late 80s and 90s, but they slowly faded as discs stopped mattering. Meanwhile, ONAs exploded thanks to streaming platforms, YouTube, Netflix and so on, becoming one of the main ways anime gets released today. TV is still important and steady, but this chart really shows how technology changed where anime comes out and how people watch it.

# %% [markdown]
# ### How are productions and studios related?

# %%
# Drop rows where there is no primary studio
anime_studios = anime_clean[anime_clean['primary_studio'].notna()].copy()

# Aggregation: Count productions and calculate mean score
studio_stats = anime_studios.groupby('primary_studio').agg(
    production_count=('mal_id', 'count'),
    avg_score=('score', 'mean'),
    total_favorites=('favorites', 'sum')
).reset_index()

# Filter: Only keep studios with > 20 productions to avoid noise
top_studios = studio_stats[studio_stats['production_count'] > 20]

# --- TREEMAP (Studio Production Volume) ---
fig_tree = px.treemap(
    top_studios,
    path=[px.Constant("All Studios"), 'primary_studio'],
    values='production_count',
    color='avg_score',
    color_continuous_scale='RdBu',  # Red = Bad, Blue = Good
    title='Studio Dominance: Box Size = Production Volume, Color = Average Score',
    hover_data=['avg_score']
)
fig_tree.update_layout(margin=dict(t=50, l=25, r=25, b=25))
fig_tree.show()

# %% [markdown]
# Here we can observe how a few giant studios like Toei Animation, Sunrise, J.C. Staff and TMS Entertainment dominate anime production volume, but high output doesn’t automatically mean higher quality—some smaller studios (e.g., Bones, Kyoto Animation, Madhouse) achieve higher average scores with fewer titles, suggesting more consistent critical success.

# %% [markdown]
# ### But out of all of these, who is the 'Prestige' studio?

# %%
top_studios = top_studios.copy()

# pick top 20 by favorites (change column if you want)
top20_idx = top_studios.nlargest(20, "total_favorites").index

# create labels for only the top 20 studios
top_studios["label"] = ""
top_studios.loc[top20_idx, "label"] = top_studios.loc[top20_idx, "primary_studio"]

# --- SCATTER (Quality vs Quantity) ---
fig_scatter = px.scatter(
    top_studios,
    x="production_count",
    y="avg_score",
    size="total_favorites",
    text="label",
    title="Studio Strategy: Quality (Y) vs. Quantity (X)",
    labels={
        "production_count": "Total Anime Produced",
        "avg_score": "Average Score"
    },
    height=600
)

fig_scatter.update_traces(
    mode="markers+text",
    textposition="top center",
    textfont=dict(size=12)
)

fig_scatter.show()

# %% [markdown]
# Studios that make tons of anime don’t always make the best ones. Big producers like J.C. Staff, Studio Pierrot, and TMS release a huge number of shows, but their average ratings are just “good.” Meanwhile, studios like Kyoto Animation, Bones, Wit Studio, CloverWorks, and ufotable produce fewer titles but usually get higher scores. The bubble size also matters: it represents how many users marked those shows as favorites. This means the “quality-first” studios don’t just score well — their anime are also loved more by fans.

# %% [markdown]
# ## CHAPTER 2: The Content and the Quality
#
#
# In this chapter, we want to unravel if the productions per se are actually liked by users
#
# ### Let's try to answer this question first: Which genre is the most prevalent?

# %%
# Count by genres
genres_counts = anime_genres["genres"].value_counts().sort_index()

# bar plot
genres_counts.sort_values(ascending=False).plot(kind="bar")
plt.xlabel("Genres")
plt.ylabel("Count")
plt.title("Anime Genre Distribution (Descending Order) ")
plt.tight_layout()
plt.show()

# %% [markdown]
# Comedy dominates in quantity. But does it also dominate in quality or preference over time?

# %%
# AGGREGATION 
# We group by Year and Genre to get the count
genre_trends = filtered_data.groupby(['start_year', 'genres']).size().reset_index(name='count')

# --- Interactive LINE CHART (Anime Production by Genre Over Time) ---
fig_volume = px.line(
    genre_trends,
    x='start_year',
    y='count',
    color='genres',
    title='A. Trends Over the Years: Evolution of Anime Production by Genre',
    labels={'start_year': 'Year', 'count': 'Number of Anime Produced', 'genres': 'Genre'},
    template="plotly_dark"
)

# Refine the layout to handle the x-axis range better
fig_volume.update_xaxes(range=[1960, 2024]) # Focus on the modern era
fig_volume.show()

# %% [markdown]
# Anime production did not grow evenly across genres, but followed clear waves driven by audience taste and cultural trends.
# Until the late 1980s, production was limited and fairly balanced. From the 1990s onward, the number of anime increased sharply, but only some genres truly exploded. Comedy, Action, Fantasy, and Adventure became dominant, while others grew more slowly and remained niche.

# %% [markdown]
# ### Have audience preferences shifted?
#
# We use a Heatmap to visualize the average score of top genres over decades. This allows us to see not just what is produced, but what is rated highly.

# %%
# Select top 15 genres by total frequency to keep the chart readable
top_genres = anime_genres['genres'].value_counts().head(15).index

# Filter the genre dataframe (make a copy to avoid SettingWithCopy warnings)
genre_trend = anime_genres[anime_genres['genres'].isin(top_genres)].copy()

# Create a 'decade' column for aggregation
genre_trend['decade'] = (genre_trend['start_year'] // 10) * 10

# Pivot table: Index=Genres, Columns=Decade, Values=Mean Score
# This produces the matrix used by the heatmap to show score trends over decades
heatmap_data = genre_trend.pivot_table(index='genres', columns='decade', values='score', aggfunc='mean')

# --- HEATMAP (Average Anime Score by Genre and Decade) ---
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=.5)
plt.title("Average Anime Score by Genre and Decade")
plt.xlabel("Decade")
plt.ylabel("Genre")
plt.show()

# %% [markdown]
# Although the heatmap shows values starting from the 1910s, these are not errors: very early Japanese animated productions really exist! These decades contain very few titles compared to modern years, so their averages should be interpreted cautiously.

# %% [markdown]
# ### Are there any genre preferred from specific studios? Do they all produce the same genres?

# %%
# Top 10 studios
top_studios = anime_genres["primary_studio"].value_counts().head(10).index

# Filter only those studios
specialization_data = anime_genres[anime_genres["primary_studio"].isin(top_studios)]

# Top 10 genres (to keep readable)
specialization_data = specialization_data[specialization_data["genres"].isin(specialization_data["genres"].value_counts().head(10).index)]


# Pivot table (needed for the heatmap)
studio_genre_pivot = pd.crosstab(specialization_data["primary_studio"],specialization_data["genres"])

# --- HEATMAP (Studio Specialization by Genre) ---
plt.figure(figsize=(12, 8))
sns.heatmap(
    studio_genre_pivot,
    annot=True,
    fmt="d",
    cmap="Purples",
    linewidths=.5
)

plt.title("Number of Productions by Genre", fontsize=14)
plt.ylabel("Studio")
plt.xlabel("Genre")
plt.show()

# %% [markdown]
# Studios aren’t all doing the same thing—most of them have clear comfort zones. Toei lives in Action/Adventure, Sunrise is basically a Sci-Fi machine, and J.C. Staff + TMS carry Comedy. Meanwhile Madhouse spreads across everything, but still leans toward Drama/Fantasy. In short: the anime industry is full of ‘specialist studios’ instead of generalists.

# %% [markdown]
# ### Anime has 4 main target demographics: Shounen (Boys), Shojo (Girls), Seinen (Adult Men), Josei (Adult Women).
# Which one of these target audience scores higher than the others?

# %%
# Drop missing demographics
anime_genres = anime_genres[anime_genres["demographics"].notna()]
#We use anime_genres dataframe which has exploded demographics 

# --- BOX PLOT (Target Audience vs. Critical Acclaim) ---
fig = px.box(
    anime_genres,
    x="demographics",
    y="score",
    color="demographics",
    title="Target Audience vs. Critical Acclaim",
    points="suspectedoutliers",
    category_orders={"demographics": ["Kids", "Shounen", "Shoujo", "Seinen", "Josei"]}
    )

fig.update_xaxes(title_text="Demographics (ordered by target age)")
fig.update_yaxes(title_text="Score")

fig.show()

# %% [markdown]
# Scores don’t change dramatically across demographics, but Kids anime clearly performs worse, while Seinen shows the largest variability with both more masterpieces and more flops.

# %% [markdown]
# Now let's have a look at the average score of anime based on demographic data, to see whether it changes or stays roughly the same across different age groups.

# %%
# Pivot table: Index=Genres, Columns=Decade, Values=Mean Score
heatmap_data = genre_trend.pivot_table(index='genres', columns='demographics', values='score', aggfunc='mean')

sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=.5)
plt.title("Average Anime Score by Genre and Demographics")
plt.xlabel("Demographics")
plt.ylabel("Genre")
plt.show()

# %% [markdown]
# It is evident that the Kids demographic has a lower average score, around 6, while the other age groups have an average closer to 7. This may be because anime aimed at children often feature simple plots, humor, or educational content, which can be less appreciated by older viewers or those who prefer more complex stories, resulting in lower average ratings.

# %% [markdown]
# ### Talking about score, aren't you curious to know what is the overall average?

# %%
avg_rating = anime_details_df['score'].mean()

# --- GAUGE (Average Anime Score) ---
fig = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = avg_rating,
    title = {'text': "Average Anime Score"},
    gauge = {'axis': {'range': [1, 10]},
             'bar': {'color': "darkblue"},
             'steps': [
                 {'range': [1, 5], 'color': "red"},
                 {'range': [5, 7], 'color': "yellow"},
                 {'range': [7, 10], 'color': "green"}]}
))
fig.show()

# %% [markdown]
# The average score (6.39) falls in the yellow area of the gauge, meaning that, overall, anime quality is perceived as decent but not exceptional.
# ## But are the top 10 universally loved or divisive?

# %%
# Identify the Top 10 Most Watched Anime
top_10_ids = anime_clean.nlargest(10, 'members')['mal_id']
top_10_titles = anime_clean.set_index('mal_id').loc[top_10_ids, 'title']

# Filter ratings_df
# Ideally, you do this merge carefully.
top_ratings = ratings_df[ratings_df['anime_id'].isin(top_10_ids)].copy()

# Add Titles for the plot
top_ratings['anime_title'] = top_ratings['anime_id'].map(top_10_titles)

# Filter out ratings with a score of 0
top_ratings = top_ratings[top_ratings['score'] != 0]

# --- VIOLIN PLOT (Rating Distribution of the Top 10 Anime) ---
plt.figure(figsize=(14, 8))
sns.violinplot(
    data=top_ratings,
    x='score',
    y='anime_title',
    density_norm='width',
    hue="anime_title",
    palette='muted',
    inner='quartile' # Show the median and quartiles inside
)

plt.title("Rating Distribution of the Top 10 Anime", fontsize=16)
plt.xlabel("User Score given (1-10)")
plt.ylabel("")
plt.xlim(0, 11) # Scores are 1-10
plt.show()

# %% [markdown]
# Some top anime are “universally loved” with ratings clustered around 9–10 (like Fullmetal Alchemist: Brotherhood, Hunter x Hunter, Shingeki no Kyojin), while others are far more divisive, showing wide spreads across all scores (like Sword Art Online, Tokyo Ghoul, and Naruto).

# %% [markdown]
# ### In this sea of ​​content, are there masterpieces that no one watches?
# ### Are there any hidden gems?
# Let's look for shows that are amazing (High Score) but ignored (Low Popularity).

# %%
# Identify candidate 'hidden gems' — well-rated but not broadly popular shows
# We require a minimum number of members to avoid tiny-sample artifacts
gem_data = anime_clean[(anime_clean['score'] > 0) & (anime_clean['members'] > 1000)] # Minimum threshhold to be a "gem" not just a glitch   

# --- SCATTER PLOT (Hidden Gems) ---
fig = px.scatter(
    gem_data,
    x="members",
    y="score",
    color="type",
    hover_name="title",
    log_x=True, # Essential for popularity
    title="The Search for Hidden Gems (Top Left Quadrant)",
    labels={'members': 'Popularity (Log Scale)', 'score': 'Score'},
    height=700
)

# Add Quadrant Lines
# "Popularity" median and "Score" median
median_pop = gem_data['members'].median()
median_score = gem_data['score'].median()

fig.add_vline(x=median_pop, line_width=1, line_dash="dash", line_color="grey")
fig.add_hline(y=median_score, line_width=1, line_dash="dash", line_color="grey")

# Annotation
fig.add_annotation(
    x=np.log10(median_pop) - 0.5, # Adjusted for log scale visual placement
    y=median_score + 2.5,
    text="HIDDEN GEMS\\n(High Score, Low Pop)",
    showarrow=False,
    font=dict(color="green", size=14)
)

fig.show()

# %% [markdown]
# By plotting score vs popularity, we can visually search for “hidden gems”: anime that are rated very highly but haven’t reached mainstream popularity yet. The general trend shows that popularity and ratings roughly rise together, but the interesting part is the top-left quadrant: there are plenty of highly rated shows that relatively few people have watched — meaning there really are underrated masterpieces buried in the dataset.

# %% [markdown]
# ## Chapter 3: Global Fandom
# Let's have a look at the anime community across the world.
# Anime has increasingly become a globalized phenomenom loved by everybody.
#
# ### How many users do we have around the world?

# %%
# Count users per country
country_counts = profiles_df['location'].value_counts().reset_index()
country_counts.columns = ['location', 'User_Count']

# Use gapminder to map country names to ISO-3 codes required by plotly
codes = px.data.gapminder()[["country", "iso_alpha"]].drop_duplicates()

# Merge counts with population data
country_counts = country_counts.merge(codes, left_on="location", right_on="country", how="left")

# --- CHOROPLETH MAP (User Distribution) ---
fig = px.choropleth(
    country_counts,
    locations="iso_alpha",
    locationmode="ISO-3",
    color="User_Count",
    hover_name="location",
    color_continuous_scale=px.colors.diverging.Portland,
    title="User Distribution by Extracted Location"
)

fig.update_layout(
    margin=dict(l=0, r=0, t=40, b=0),
    geo=dict(
        projection_scale=1.1,
        center=dict(lat=0, lon=0)
    ),
    width=1100,
    height=650
)

fig.show()

# %% [markdown]
# Japan seems to be the obvious winner. Removing japan won't make much difference in this graph.
# We could check whether this map changes if we count the percentage of people watch anime compared to the whole population of the country

# %%
# Count users per country
country_counts = profiles_df['location'].value_counts().reset_index()
country_counts.columns = ['location', 'User_Count']

# Get population + ISO-3 codes from gapminder
gap = px.data.gapminder()[['country', 'iso_alpha', 'year', 'pop']]

# Take the latest year per country
gap_latest = gap.sort_values('year').drop_duplicates('country', keep='last')

# Merge your counts with population data
country_counts = country_counts.merge(gap_latest,left_on='location', right_on='country', how='left')

# Compute users percentage
country_counts['users_percent'] = (country_counts['User_Count'] / country_counts['pop'] * 100)

# --- CHOROPLETH MAP (User Distribution normalized by Population) ---
fig = px.choropleth(
    country_counts,
    locations="iso_alpha",
    locationmode='ISO-3',
    color="users_percent",
    hover_name="location",
    hover_data={
        "User_Count": True,
        "pop": True,
        "users_percent": ':.2f'
    },
    color_continuous_scale=px.colors.diverging.Portland,
    title='Anime Users per 100k Inhabitants by Country'
)

fig.update_layout(
    margin=dict(l=0, r=0, t=40, b=0),
    geo=dict(
        projection_scale=1.1,
        center=dict(lat=0, lon=0)
    ),
    width=1100,
    height=650
)

fig.show()

# %% [markdown]
# This way we can tell Australia becomes much more interesting.
# Though we could use a logarithmic scale in order to visualize better the differences between other countries too.

# %%
# To better visualize countries with low percentages, we use a log scale
country_counts['users_percent_log'] = np.log10(country_counts['users_percent'].replace(0, np.nan))

# --- CHOROPLETH MAP (User Distribution normalized by Population, using log scale) ---
fig = px.choropleth(
    country_counts,
    locations="iso_alpha",
    locationmode='ISO-3',
    color="users_percent_log",
    hover_name="location",
    hover_data={
        "User_Count": True,
        "pop": True,
        "users_percent": ':.2f'
    },
    color_continuous_scale=px.colors.diverging.Portland,
    title='Anime Users per 100k Inhabitants by Country'
)

fig.update_layout(
    margin=dict(l=0, r=0, t=40, b=0),
    geo=dict(
        projection_scale=1.1,  # zoom in slightly
        center=dict(lat=0, lon=0)
    ),
    width=1100,
    height=650
)

fig.show()

# %% [markdown]
# From the previous map we couldn't tell exactly which were the countries the least percentage of users.
# With the logarithmic scale we can tell India has the least amount of people (compared to its own population) watching anime, followed by China and then Indonesia and Brasil on the same level.
# ## Now let's make the map animated, showing the total users per year

# %%
# Convert joined column to datetime and extract year
profiles_df["joined"] = pd.to_datetime(profiles_df["joined"], errors="coerce")
profiles_df["join_year"] = profiles_df["joined"].dt.year

# Keep only rows with a year and a location
df = profiles_df.dropna(subset=["join_year", "location"]).copy()

# Count users per country per year
# If "username" exists in profiles_df, count unique users (better)
country_counts = (df.groupby(["join_year", "location"])["username"].nunique().reset_index(name="User_Count"))

# Get population + ISO-3 codes from gapminder (latest available)
gap = px.data.gapminder()[['country', 'iso_alpha', 'year', 'pop']]
gap_latest = gap.sort_values('year').drop_duplicates('country', keep='last')

# Merge your counts with population data
country_counts = country_counts.merge(gap_latest,left_on='location', right_on='country', how='left')

# Compute users percentage
country_counts["users_percent"] = (country_counts["User_Count"] / country_counts["pop"]) * 100

# Log scale for low percentages (avoid log(0))
country_counts["users_percent_log"] = np.log10(country_counts["users_percent"].replace(0, np.nan))


# --- CHOROPLETH MAP (User Distribution normalized by Population, using log scale) ---
fig = px.choropleth(
    country_counts,
    locations="iso_alpha",
    locationmode='ISO-3',
    color="users_percent_log",
    hover_name="location",
    hover_data={
        "User_Count": True,
        "pop": True,
        "users_percent": ':.2f'
    },
    animation_frame="join_year",
    color_continuous_scale=px.colors.diverging.Portland,
    title='Anime Users per 100k Inhabitants by Country'
)

fig.update_layout(
    margin=dict(l=0, r=0, t=40, b=0),
    geo=dict(
        projection_scale=1.1,  # zoom in slightly
        center=dict(lat=0, lon=0)
    ),
    width=1100,
    height=650
)

fig.show()

# %% [markdown]
# The animated map shows how the geographic distribution of users on the platform evolves over time.
# It is important to note that the dataset starts in 2004, so the visualization does not represent the origin of anime fandom in general, but only the earliest available records of this specific website.
# In 2004, users are recorded only in Spain and Germany, which likely reflects the initial availability or early adoption of the platform in those countries rather than a real absence of users elsewhere.
# In the following years, especially between 2005 and 2006, users from additional countries such as Argentina, Vietnam, and Japan begin to appear.
# Over time, more countries from different continents are added, showing a rapid international growth of the platform and an increasing global reach.

# %% [markdown]
# The globalization of anime is supported by the voice actors and the licensors who are bringing the anime to the West.

# %%
# Count distinct roles by language
lang_counts = person_voice_works_df['language'].value_counts().reset_index()
lang_counts.columns = ['language', 'role_count']

# --- BAR CHART (Voice Acting Languages) ---
fig = px.bar(
    lang_counts.head(10),
    x='role_count',
    y='language',
    orientation='h',
    title='Voice Acting Languages in Anime (Top 10 Including Japanese)',
    color='role_count',
    color_continuous_scale='Viridis'
)
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()

# %% [markdown]
# Japanese is the clear winner here (we had no doubt about it).
# But let's have a better look at how other languages across the world are used as voice acting languages.

# %%
# Separate Japanese (Dominant) from Others to make the chart readable
non_jp = lang_counts[lang_counts['language'] != 'Japanese']

# --- BAR CHART (Voice Acting Languages, Log Scale) ---
fig = px.bar(
    non_jp.head(10), # Top 10 non-Japanese languages
    x='role_count',
    y='language',
    orientation='h',
    title='Globalization of Anime: Top Non-Japanese Voice Acting Languages',
    color='role_count',
    color_continuous_scale='Viridis'
)
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.update_xaxes(type='log')

fig.show()

# %% [markdown]
# ### Anime reaches the global West through Licensors. Who owns the market?

# %%
# Explode Licensors into separate rows so each licensor can be counted individually
anime_lic = anime_clean.assign(licensors=anime_clean['licensors'].apply(ast.literal_eval)).explode('licensors')

# Remove Unknown / None
anime_lic = anime_lic[anime_lic['licensors'].notna()]

# Count occurrences per licensor
licensor_counts = anime_lic['licensors'].value_counts().reset_index()
licensor_counts.columns = ['Licensor', 'Count']

# --- PIE CHART (Market Share of Licensors) ---
fig = px.pie(
    licensor_counts,
    values='Count',
    names='Licensor',
    title='Market Share of All Anime Licensors',
    hole=0.4
)

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# This Pie Chart doesn't work because we have too many licensors, we could use a Treemap instead

# %%
# --- TREEMAP (Market Share) ---
fig = px.treemap(
    licensor_counts,
    path=['Licensor'],
    values='Count',
    title='Anime Licensors – Market Share (Treemap)'
)

fig.update_traces(textinfo="label+percent entry")
fig.show()

# %% [markdown]
# A few big names like Funimation and Sentai Filmworks take a huge chunk of the market, while most other licensors only handle a very small share. So even though there are many companies in the space, real “power” is mostly in the hands of just a handful of them.

# %% [markdown]
# ### Let's jump now to the users, does the joining date influence score?
#
# First, we want to analyze the trend of registrations since the platform's launch year

# %%
# Extracting the year of registration
profiles_df['joined_year'] = profiles_df['joined'].dt.year

# Counting how many registrations there are for each year
joined_per_year = profiles_df.groupby('joined_year').size()

plt.plot(joined_per_year.index, joined_per_year.values, marker='o', color="skyblue")

plt.title("Join by year")
plt.xlabel("Year")
plt.ylabel("Number of join")
plt.grid(True, axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# We can observe a generally linear growth in registrations on MyAnimeList starting from 2004, the year the platform was launched, up to the present.
# The only evident anomaly occurs in 2022, when the number of registrations is roughly half compared to the adjacent years. No historical events or platform-specific factors appear to explain such a marked drop.
#
# One possible interpretation relates to the lockdown period: in April 2020, there was indeed a noticeable spike in registrations compared to the linear growth trend, likely due to increased time spent online and greater consumption of entertainment content. With the end of the lockdown, in 2022, the number of registrations seems to return to more regular values, although the observed drop still appears unusually sharp, suggesting a potential bias in the data.
#
# The year 2023, on the other hand, shows strong growth, with a real boom in registrations, while in 2024 and 2025 the trend returns to being consistent with the growth observed in previous years. It should also be noted that data for 2025 are partial and therefore not fully comparable with previous years.
#
# Finally, the particularly sharp increase starting from July 2023 can be partially explained by the release of highly anticipated and popular anime during that period. Based on research, it is plausible that these events contributed to attracting new users to the platform, boosting registrations and activity on MyAnimeList.

# %%
# We select only the columns of interest and filter to completed
completed_df = ratings_df[(ratings_df['status'] == 'completed') & (ratings_df['score'] > 0)][['username', 'anime_id', 'score']].copy()

# Add date_joined from user dataset
completed_df = completed_df.merge(
    profiles_df[['username', 'joined']],
    on='username',
    how='left'
)

# to year
completed_df['join_year'] = completed_df['joined'].dt.year

# Remove rows with NaN in join_year o score
completed_df = completed_df.dropna(subset=['join_year', 'score'])

# Convert join_year to int
completed_df['join_year'] = completed_df['join_year'].astype(int)

# Boxplot
sns.boxplot(x='join_year', y='score', data=completed_df)
plt.title("Distribution of scores by year of joining")
plt.xlabel("Join year")
plt.ylabel("Score")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The graph shows a clear divide between veterans and newcomers, users who joined between 2007 and 2019 are more critical, with a steady average score of 7. However, those who joined from 2020 onwards are much more enthusiastic, jumping to an average of 8.

# %%
# Filter ratings to only 'completed' and 'dropped' with score > 0
ratings_cd_df = ratings_df[(ratings_df['status'].isin(['completed', 'dropped'])) & (ratings_df['score'] > 0)].copy()

# Rename columns and merge with anime details
ratings_cd_df = ratings_cd_df.rename(columns={'anime_id': 'mal_id'})
ratings_cd_df = ratings_cd_df.merge(
    anime_details_df[['mal_id', 'rank']],
    on='mal_id',
    how='left'
)

# Drop rows with NaN in rank or score, then sort by rank
ratings_cd_df = ratings_cd_df.dropna(subset=['rank', 'score'])
ratings_cd_df = ratings_cd_df.sort_values('rank')

# Create columns of bin
ratings_cd_df['rank_bin'] = pd.cut(
    ratings_cd_df['rank'],
    bins=[0, 5500, 11000, 16500, 22000],
    labels=['0-5500', '5501-11000', '11001- 16500', '16501-22000']
)

# Violin plot
sns.violinplot(
    x='rank_bin',
    y='score',      
    hue='status',
    data=ratings_cd_df,
    split=True,
    inner='quartile'
)

plt.title("Ranking distribution by status")
plt.xlabel("Ranking")
plt.ylabel("Anime score")
plt.legend(title='Status', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# The graph shows that the ranking acts as a true quality filter. In the top tiers, we find the most beloved works, where even those who decide not to finish watching still assign a decent score. In contrast, in the bottom ranking tier, the score plummets because dropping the series is almost always accompanied by a negative rating: those who quit these anime tend to give the lowest possible score, turning simple disinterest into a clear rejection of the content. Therefore, we can see that there is a correlation both between high ranking and dropped anime, and between high ranking and low scores.

# %% [markdown]
# ### When are our users born? Is there any difference in rating by age?

# %%
# Birthday extraction
profiles_df['birthday'] = pd.to_datetime(profiles_df['birthday'], errors='coerce')
profiles_df['bday_year'] = profiles_df['birthday'].dt.year

# Compute average score per user BUT only valid scores 1–10
valid_ratings = ratings_df[ratings_df['score'].between(1, 10)]
avg_user_score = (valid_ratings.groupby('username')['score'].mean().reset_index())

# Merge
user_history = pd.merge(profiles_df[['username', 'bday_year']],avg_user_score,on='username',how='inner')

# Group
cohort_analysis = (user_history.groupby('bday_year')['score'].agg(avg_score='mean', users='count').reset_index())
cohort_analysis = cohort_analysis[cohort_analysis['users'] >= 50]

# --- BAR CHART (Users Per Birth Year Cohort) ---
fig_users = px.bar(
    cohort_analysis,
    x='bday_year',
    y='users',
    title='Users Per Birth Year Cohort'
)

# --- LINE CHART (Cohort Analysis of Ratings) ---
fig = px.line(
    cohort_analysis,
    x='bday_year',
    y='avg_score',
    markers=True,
    title='Do Different Age Cohorts Rate Differently?',
    labels={'bday_year': 'Birth Year', 'avg_score': 'Average Score Given'}
)

fig_users.show()
fig.show()

# %% [markdown]
# Looking only at cohorts with enough users to be meaningful, we find that:
#
# 1985–1995 cohorts
# Average ratings are fairly stable around ~7.6–7.7, suggesting consistent, balanced rating behavior.
#
# Late 1990s → Early 2000s cohorts
# There is a gradual decline toward ~7.4–7.5.
# Possible explanation: these users rate more shows, including mid-tier titles, and MAL became mainstream in their era → broader viewing → slightly harsher averages.
#
# Post-2008 cohorts
# Scores jump upward again. This could reflect: fewer users, tendency to rate only popular modern titles or younger users being more enthusiastic.

# %% [markdown]
# ### How many anime do people watch across their life?
# Do older people still watch anime?

# %%
# Convert birthday to datetime, coerce errors to NaT
profiles_df['birthday'] = pd.to_datetime(profiles_df['birthday'], errors='coerce')

# Calculate Age (Assuming dataset is current to ~2025)
# (Vectorized date math)
profiles_df['age'] = 2025 - profiles_df['birthday'].dt.year

profiles_df['completed'] = pd.to_numeric(profiles_df['completed'], errors='coerce')
profiles_df['plan_to_watch'] = pd.to_numeric(profiles_df['plan_to_watch'], errors='coerce')

# Keep only reasonable ages
profiles_df = profiles_df[profiles_df['age'].between(10, 50)]

# ---- AGE BUCKETS ----
profiles_df['age_group'] = (profiles_df['age'] // 2) * 2   # groups like 12,14,16...

# Mean per bucket
age_trends = (profiles_df.groupby('age_group')[['completed', 'plan_to_watch']].mean().reset_index().sort_values('age_group'))

# ---- LINE CHART (Anime Completed Over Time) ----
plt.figure(figsize=(12,6))
sns.lineplot(data=age_trends, x='age_group', y='completed',
             label='Completed Anime', color='blue', linewidth=2.5)

sns.lineplot(data=age_trends, x='age_group', y='plan_to_watch',
             label='Plan to Watch', color='orange', linestyle='--')

plt.title("The Lifecycle of an Otaku: Age vs Anime Completed", fontsize=14)
plt.xlabel("User Age (Grouped)")
plt.ylabel("Average Number of Shows")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Younger users tend to watch more anime on average, steadily increasing through their teens and early adulthood. Once people hit their late 20s and 30s, the curve starts flattening or dropping slightly — probably because life kicks in (work, family, less free time). Interestingly, even if they slow down watching, their “Plan to Watch” list doesn’t disappear, meaning the passion stays even if time doesn’t.

# %% [markdown]
# ### Does user gender make any difference when giving the score to an anime?

# %%
# Make sure score is numeric
ratings_df["score"] = pd.to_numeric(ratings_df["score"], errors="coerce")

# Merge ratings + profiles to attach gender to each rating so we can analyze by gender
merged_df = ratings_df.merge(profiles_df[["username", "gender"]], on="username", how="inner")

# Keep valid data
merged_df = merged_df[merged_df["gender"].notna() & merged_df["score"].between(1, 10)]

ratings_count_df = (merged_df.groupby(['gender','score']).size().reset_index(name='count'))

# Compute total ratings per gender
totals = ratings_count_df.groupby('gender')['count'].transform('sum')

# Create percent col
ratings_count_df['percent'] = ratings_count_df['count'] / totals * 100

# --- LINE CHART (Rating Distribution by Gender) ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ratings_count_df,
    x='score',
    y='percent',
    hue='gender',
    marker='o'
)

plt.title('Rating Distribution by Gender (Percent)')
plt.xlabel('Rating')
plt.ylabel('Percentage of Ratings')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# We used to percentages instead of raw counts so we could compare how each gender actually rates, instead of just seeing which group has more people in it.
# All genders rate pretty similarly overall, with most ratings clustered around 7 and 8. It looks like non-binary users show a bit more “spread”, giving both more low scores and more 10s compared to the others, while males and females look slightly more conservative around the middle.
#
# These differences should be interpreted with caution, as gender groups are not equally represented in the dataset.

# %%
# Filter profiles for gender (Male/Female only for binary comparison)
users = profiles_df[profiles_df['gender'].isin(['Male', 'Female'])][['username', 'gender']]

# Merge Ratings with Users (full dataset, scores > 0 only)
valid_ratings = ratings_df[ratings_df['score'] > 0]
user_ratings = pd.merge(valid_ratings, users, on='username', how='inner')

# Merge with Anime to get Genres
# We need to use the exploded 'anime_genres', but just the ID and Genre columns
anime_genre_map = anime_genres[['mal_id', 'genres', 'title']]
full_data = pd.merge(user_ratings, anime_genre_map, left_on='anime_id', right_on='mal_id', how='inner')

# Choose an order: top 10 most rated genres in this merged dataset
genre_order = (
    full_data['genres']
    .value_counts()
    .head(10)
    .index
    .tolist()
)
# Keep only those genres from the full rating data
full_data_top = full_data[full_data['genres'].isin(genre_order)]

# --- VIOLIN PLOT (Score Distribution by Genre and Gender) ---
plt.figure(figsize=(14, 7))
sns.violinplot(
    data=full_data_top,
    x='genres',
    y='score',
    hue='gender',
    order=genre_order,
    split=True,
    inner='quartile',
    cut=0
)
plt.xticks(rotation=45)
plt.title("Score Distribution by Genre and Gender", fontsize=15)
plt.xlabel("Genre")
plt.ylabel("Score")
plt.legend(title="Gender")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %% [markdown]
# We first tried to use a violin plot to compare scores by gender. When all three gender categories were included, the chart became messy and hard to read, so we decided to focus only on Male and Female users, since they make up most of the dataset.
# Non-binary users are still included in the data overall, but weren't used in this specific visualization because there are fewer of them and the plot would have become confusing.

# %% [markdown]
# From the violin plot we can see that male and female users rate anime in a very similar way. Most ratings for both genders stay between 6 and 9, and the shapes overlap a lot. This means gender doesn’t seem to strongly influence how people rate anime in general.

# %% [markdown]
# ### How big is the gap between male and female when it comes to rating specific genres?

# %%
#Using the same data we just computed, we could now visualize the gender preference gap.

# Aggregation: Mean score per Genre per Gender (unstack is used to pivot gender into columns)
# This results in a table where each row is a genre and columns are genders with mean scores
genre_gender_scores = full_data.groupby(['genres', 'gender'])['score'].mean().unstack()

# Calculate Gap and Filter for Top Genres
comparison = genre_gender_scores.loc[genre_gender_scores.index].copy()
comparison['diff'] = comparison['Female'] - comparison['Male']
comparison = comparison.sort_values('diff')

# Order genres by the same gap used above
genre_order = comparison.index.tolist()

# --- GENDER PREFERENCE GAP PLOT ---
plt.figure(figsize=(10, 8))
plt.hlines(
    y=comparison.index,
    xmin=0,
    xmax=comparison['diff'],
    color='C0',
    alpha=0.8,
    linewidth=5
)
plt.axvline(0, color='black', linestyle='--', linewidth=1) 
plt.title("Gender Preference Gap (Female Score - Male Score)", fontsize=15)
plt.xlabel("Difference in Average Score (Positive = Female Preferred)", fontsize=12)
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# When we zoom in on the difference in average scores, the gap plot shows that, on average, female users tend to rate slightly higher than male users across almost all genres. The difference is small but consistent, meaning women are usually just a bit more positive when giving scores compared to men.
# Though we can see how the "Boys love" genre is mostly loved by women, while there's a slight preference towards "Erotica" from male.

# %% [markdown]
# ### Conclusion
#
# The analysis shows that anime has not only increased in quantity, but has fundamentally changed in structure, distribution, and audience reach.
# Production has grown steadily and proven to be highly resilient: even major global events, such as the COVID-19 pandemic, caused only temporary disruptions rather than long-term decline.
#
# Technology played a central role in this evolution. Physical formats gradually lost importance, while online platforms enabled anime to reach a global audience more quickly and efficiently.
# As a result, new generations of viewers joined the community, bringing different viewing habits and rating behaviors compared to long-time users.
#
# At the same time, the data reveals that high production volume does not necessarily imply higher quality. Some studios release many titles with average reception, while others focus on fewer productions and achieve stronger critical and fan appreciation.
# Similarly, audience preferences remain surprisingly stable across genres and demographics, with only subtle differences linked to age, experience, and cultural context.
#
# Anime became a global phenomenon not because audience taste radically changed, but because technology transformed how anime is produced, distributed, and discovered.
