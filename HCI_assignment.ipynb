# %% [markdown]
# ### Beginning of the Assignment - exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %%
df = pd.read_csv('datasets/PHIL DATA SET/character_nicknames.csv')

# %%
df = pd.read_csv('datasets/PHIL DATA SET/details.csv')

# %%
df = pd.read_csv('datasets/PHIL DATA SET/favs.csv')

# %%
df = pd.read_csv('datasets/PHIL DATA SET/person_alternate_names.csv.csv')

# %%
df = pd.read_csv('datasets/PHIL DATA SET/person_anime_works.csv.csv')

# %%
df = pd.read_csv('datasets/PHIL DATA SET/person_details.csv.csv')

# %%
df = pd.read_csv('datasets/PHIL DATA SET/stats.csv')

# %% [markdown]
# ##### First look

# %%
df.shape
# Out:
# (28955, 29)

# %%
df.head()
# Out:
#    mal_id                             title        title_japanese  \
# 0   59356                          -Socket-              -socket-
# 1   56036                            ......                ......
# 2    2928              .hack//G.U. Returner  .HACK//G.U. RETURNER
# 3    3269               .hack//G.U. Trilogy   .hack//G.U. Trilogy
# 4    4469  .hack//G.U. Trilogy: Parody Mode   .hack//G.U. Trilogy
#
#                                                  url  \
# 0       https://myanimelist.net/anime/59356/-Socket-
# 1              https://myanimelist.net/anime/56036/-
# 2  https://myanimelist.net/anime/2928/hack__GU_Re...
# 3  https://myanimelist.net/anime/3269/hack__GU_Tr...
# 4  https://myanimelist.net/anime/4469/hack__GU_Tr...
#
#                                            image_url     type  \
# 0  https://cdn.myanimelist.net/images/anime/1043/...    Movie
# 1  https://cdn.myanimelist.net/images/anime/1057/...    Music
# ...

# %%
df.columns
#will list all the columns. Not necessary here but kept as a pattern to follow with the following files
# Out:
# Index(['character_mal_id', 'nickname'], dtype='object')

# %%
df.dtypes
# Out:
# character_mal_id     int64
# nickname            object
# dtype: object

# %%
df.describe()
#not needed here because it should just be ids
# Out:
#        character_mal_id
# count      37080.000000
# mean      115767.769579
# std        87596.063426
# min            3.000000
# 25%        30541.750000
# 50%       109656.000000
# 75%       192520.750000
# max       282255.000000

# %% [markdown]
# ### Data preparation (cleaning)

# %% [markdown]
# On the first dataset we may need to check for duplicates
